# %%
import pandas as pd

def standardize_data(input_file, output_file):
    print(f"Reading data from {input_file}...")
    df = pd.read_csv(input_file)
    
    print("\nColumn names:", df.columns.tolist())

    df['Bird Species'] = df['Bird Species'].str.strip()
    
    print(f"\nSaving standardized data to {output_file}...")
    df.to_csv(output_file, index=False)
    
    print(f"\nStandardization complete. Data saved to {output_file}")
    
    return df

# %%
standardize_data('raw_data/2016_CBCM_birds_willowbrook.csv', 'standard_data/2016_CBCM_birds_willowbrook.csv')
# Out:
# Reading data from raw_data/2016_CBCM_birds_willowbrook.csv...
#
# Column names: ['Chart Number', 'Bird Species', 'Admission Date', 'When Captured', 'Age', 'Sex', 'Address - Captured', 'City - Captured', 'Injury Cause', 'Status']
#
# Saving standardized data to standard_data/2016_CBCM_birds_willowbrook.csv...
#
# Standardization complete. Data saved to standard_data/2016_CBCM_birds_willowbrook.csv
#      Chart Number       Bird Species Admission Date    When Captured  Age  \
# 0      2016-00012    Red-tailed Hawk     06.01.2016   1/6/16 1:30 PM    A
# 1      2016-00014       Canada Goose     06.01.2016      1/6/16 3 PM    A
# 2      2016-00016      Cooper's Hawk     07.01.2016  1/7/16 10:30 AM    A
# 3      2016-00019       Canada Goose     08.01.2016      1/8/16 2 PM    A
# 4      2016-00031  Northern Cardinal     12.01.2016          1/11/16    A
# ...           ...                ...            ...              ...  ...
# ...
